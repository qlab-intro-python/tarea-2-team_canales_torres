# %% [markdown]
# # **Tarea Nº 2**

# %%
# Calificación: 19

# %% [markdown]
# Curso:          Fundamentos de Programación en Python para Macroeconomía y Finanzas
# Profesor:       Victor Fuentes Campos

# %% [markdown]
# - Fecha y hora de entrega: Sábado 6 de enero, 11:59pm
# - Agregue los nombres de las personas con las que discutió esta tarea: ____ Nestor Canales / Adriana Torres ______
# - Envíe su tarea haciendo el `push` de su código a su repo en GitHub Classroom:

# %% [markdown]
# ## Filtering rows

# %% [markdown]
# 1. Import the `flights.csv` dataset. Find all flights that:
#
#     a. Had an arrival delay of three or more hours
#     b. Flew to Houston (IAH or HOU)
#     c. Were operated by United, American, or Southwest
#     d. Departed in spring (March, April, and June)
#     e. Arrived more than two hours late, but didn’t leave late
#     f. Were delayed by at least an hour, but made up over 30 minutes in flight 7. Departed between midnight and 5am (inclusive)

# %%
# Solution
import pandas as pd
df = pd.read_csv('flights.csv')
df.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0           1  2013      1    1     517.0             515        2.0
# 1           2  2013      1    1     533.0             529        4.0
# 2           3  2013      1    1     542.0             540        2.0
# 3           4  2013      1    1     544.0             545       -1.0
# 4           5  2013      1    1     554.0             600       -6.0
#
#    arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0     830.0             819       11.0      UA    1545  N14228    EWR  IAH
# 1     850.0             830       20.0      UA    1714  N24211    LGA  IAH
# 2     923.0             850       33.0      AA    1141  N619AA    JFK  MIA
# 3    1004.0            1022      -18.0      B6     725  N804JB    JFK  BQN
# 4     812.0             837      -25.0      DL     461  N668DN    LGA  ATL
#
#    air_time  distance  hour  minute            time_hour
# ...

# %%
# a. Had an arrival delay of three or more hours
df_arr_delay = df.loc[(df['arr_delay'] >= 180)]
df_arr_delay.head()
# Out:
#      Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 151         152  2013      1    1     848.0            1835      853.0
# 649         650  2013      1    1    1815.0            1325      290.0
# 673         674  2013      1    1    1842.0            1422      260.0
# 746         747  2013      1    1    2006.0            1630      216.0
# 801         802  2013      1    1    2115.0            1700      255.0
#
#      arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 151    1001.0            1950      851.0      MQ    3944  N942MQ    JFK  BWI
# 649    2120.0            1542      338.0      EV    4417  N17185    EWR  OMA
# 673    1958.0            1535      263.0      EV    4633  N18120    EWR  BTV
# 746    2230.0            1848      222.0      EV    4644  N14972    EWR  SAV
# 801    2330.0            1920      250.0      9E    3347  N924XJ    JFK  CVG
#
#      air_time  distance  hour  minute            time_hour
# ...

# %%
# b. Flew to Houston (IAH or HOU)
df_dest = df.loc[(df['dest'] == 'IAH') | (df['dest'] == 'HOU')]
df_dest.head()
# Out:
#     Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0            1  2013      1    1     517.0             515        2.0
# 1            2  2013      1    1     533.0             529        4.0
# 32          33  2013      1    1     623.0             627       -4.0
# 81          82  2013      1    1     728.0             732       -4.0
# 89          90  2013      1    1     739.0             739        0.0
#
#     arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0      830.0             819       11.0      UA    1545  N14228    EWR  IAH
# 1      850.0             830       20.0      UA    1714  N24211    LGA  IAH
# 32     933.0             932        1.0      UA     496  N459UA    LGA  IAH
# 81    1041.0            1038        3.0      UA     473  N488UA    LGA  IAH
# 89    1104.0            1038       26.0      UA    1479  N37408    EWR  IAH
#
#     air_time  distance  hour  minute            time_hour
# ...

# %%
# c. Were operated by United, American, or Southwest
#United Airlines (UA), American Airlines (AA), Southwest Airlines (WN)
df_carrier = df.loc[(df['carrier'] == 'UA') | (df['carrier'] == 'AA') | (df['carrier'] == 'WN')]
df_carrier.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0           1  2013      1    1     517.0             515        2.0
# 1           2  2013      1    1     533.0             529        4.0
# 2           3  2013      1    1     542.0             540        2.0
# 5           6  2013      1    1     554.0             558       -4.0
# 9          10  2013      1    1     558.0             600       -2.0
#
#    arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 0     830.0             819       11.0      UA    1545  N14228    EWR  IAH
# 1     850.0             830       20.0      UA    1714  N24211    LGA  IAH
# 2     923.0             850       33.0      AA    1141  N619AA    JFK  MIA
# 5     740.0             728       12.0      UA    1696  N39463    EWR  ORD
# 9     753.0             745        8.0      AA     301  N3ALAA    LGA  ORD
#
#    air_time  distance  hour  minute            time_hour
# ...

# %%
# d. Departed in spring (March, April, and June)
df_month = df.loc[(df['month'] == 3) | (df['month'] == 4) | (df['month'] == 6)]
df_month.head()
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 136247      136248  2013      3    1       4.0            2159      125.0
# 136248      136249  2013      3    1      50.0            2358       52.0
# 136249      136250  2013      3    1     117.0            2245      152.0
# 136250      136251  2013      3    1     454.0             500       -6.0
# 136251      136252  2013      3    1     505.0             515      -10.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# 136247     318.0              56      142.0      B6      11  N706JB    JFK
# 136248     526.0             438       48.0      B6     707  N794JB    JFK
# 136249     223.0            2354      149.0      B6     608  N328JB    JFK
# 136250     633.0             648      -15.0      US    1117  N177US    EWR
# 136251     746.0             810      -24.0      UA     475  N527UA    EWR
#
#        dest  air_time  distance  hour  minute            time_hour
# ...

# %%
# e. Arrived more than two hours late, but didn’t leave late
df_dep_arr = df.loc[(df['dep_delay'] <= 0) & (df['arr_delay'] > 120)]
df_dep_arr.head()
# Out:
#        Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 22911       22912  2013      1   27    1419.0            1420       -1.0
# 33011       33012  2013     10    7    1350.0            1350        0.0
# 33019       33020  2013     10    7    1357.0            1359       -2.0
# 41075       41076  2013     10   16     657.0             700       -3.0
# 55985       55986  2013     11    1     658.0             700       -2.0
#
#        arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# 22911    1754.0            1550      124.0      MQ    3728  N1EAMQ    EWR
# 33011    1736.0            1526      130.0      EV    5181  N611QX    LGA
# 33019    1858.0            1654      124.0      AA    1151  N3CMAA    LGA
# 41075    1258.0            1056      122.0      B6       3  N703JB    JFK
# 55985    1329.0            1015      194.0      VX     399  N629VA    JFK
#
#       dest  air_time  distance  hour  minute            time_hour
# ...

# %%
# f. Were delayed by at least an hour, but made up over 30 minutes in flight
df_dep_arr1 = df.loc[(df['dep_delay'] > 60) & (df['arr_delay'] < -30)]
print(df_dep_arr1.head())
print('No hubieron esos vuelos.')
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, year, month, day, dep_time, sched_dep_time, dep_delay, arr_time, sched_arr_time, arr_delay, carrier, flight, tailnum, origin, dest, air_time, distance, hour, minute, time_hour]
# Index: []
# No hubieron esos vuelos.

# %%
# 7. Departed between midnight and 5am (inclusive)
df_dep_arr2 = df.loc[(df['dep_time'] >= 0) & (df['dep_time'] <= 500)]
df_dep_arr2.head()
# Out:
#       Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 842          843  2013      1    2      42.0            2359       43.0
# 843          844  2013      1    2     126.0            2250      156.0
# 844          845  2013      1    2     458.0             500       -2.0
# 1785        1786  2013      1    3      32.0            2359       33.0
# 1786        1787  2013      1    3      50.0            2145      185.0
#
#       arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 842      518.0             442       36.0      B6     707  N580JB    JFK  SJU
# 843      233.0            2359      154.0      B6      22  N636JB    JFK  SYR
# 844      703.0             650       13.0      US    1030  N162UW    EWR  CLT
# 1785     504.0             442       22.0      B6     707  N763JB    JFK  SJU
# 1786     203.0            2311      172.0      B6     104  N329JB    JFK  BUF
#
#       air_time  distance  hour  minute            time_hour
# ...

# %%
# dep_time == 2400
# Only 1 error, then no penalty

# %% [markdown]
# 2. How many flights have a missing dep_time? What other variables are missing? What might these rows represent?

# %%
# Solution
print(df.dep_time.isna().sum())
print(df.isna().sum())
print('Las otras variables que tienen missing son dep_delay, arr_time, arr_delay, tailnum, air_time.')
print('Las filas con valores nulos de la base de datos original pueden representar el ingreso erróneo de datos al sistema como desconocimiento de estos valores.')
# Out:
# 8255
# Unnamed: 0           0
# year                 0
# month                0
# day                  0
# dep_time          8255
# sched_dep_time       0
# dep_delay         8255
# arr_time          8713
# sched_arr_time       0
# arr_delay         9430
# carrier              0
# flight               0
# tailnum           2512
# origin               0
# dest                 0
# air_time          9430
# distance             0
# hour                 0
# minute               0
# time_hour            0
# dtype: int64
# Las otras variables que tienen missing son dep_delay, arr_time, arr_delay, tailnum, air_time.
# Las filas con valores nulos de la base de datos original pueden representar el ingreso erróneo de datos al sistema como desconocimiento de estos valores.

# %% [markdown]
# 3. What happens to observations **with missing values in `arr_time`** when you filter by **`arr_time == 1800`**? Why? (Hint: compare `2000 == 1800`, `1800 == 1800`, and `NA == 1800`).

# %%
# Solution
df_arr_time_null = df.loc[(df['arr_time'] == 1800)]
print(df_arr_time_null.arr_time.isna().sum())
print(2000 == 1800)
print(1800 == 1800)
# print (NA == 1800) Aquí obtengo error porque NA no se encuentra definido, lo mismo sucede si escribo NaN
print ('Los valores nulos desaparecen porque he filtrado la base de datos para que arr_time sea 1800.')
print ('Por eso, obtendré solo valores de 1800 para la columna arr_time y no los nulos u otros valores.')
# Out:
# 0
# False
# True
# Los valores nulos desaparecen porque he filtrado la base de datos para que arr_time sea 1800.
# Por eso, obtendré solo valores de 1800 para la columna arr_time y no los nulos u otros valores.

# %% [markdown]
# 4. What does `False & None` evaluate to? Why?

# %%
# Solution
print('None no evalúa porque no hay valor; mientras que False evalúa el error del valor o proposición.')
# Out:
# None no evalúa porque no hay valor; mientras que False evalúa el error del valor o proposición.

# %% [markdown]
# ## Select columns

# %% [markdown]
# 5. Brainstorm as many distinct ways as possible to select `dep_time`, `dep_delay`, `arr_time`, and `arr_delay` from `flights`.

# %%
# Solution
print(df[['dep_time','dep_delay','arr_time','arr_delay']].head())
print(df.iloc[:, [4, 6, 7, 9]].head())
print(df.loc[:, ["dep_time", "dep_delay", "arr_time", "arr_delay"]].head())
# Out:
#    dep_time  dep_delay  arr_time  arr_delay
# 0     517.0        2.0     830.0       11.0
# 1     533.0        4.0     850.0       20.0
# 2     542.0        2.0     923.0       33.0
# 3     544.0       -1.0    1004.0      -18.0
# 4     554.0       -6.0     812.0      -25.0
#    dep_time  dep_delay  arr_time  arr_delay
# 0     517.0        2.0     830.0       11.0
# 1     533.0        4.0     850.0       20.0
# 2     542.0        2.0     923.0       33.0
# 3     544.0       -1.0    1004.0      -18.0
# 4     554.0       -6.0     812.0      -25.0
#    dep_time  dep_delay  arr_time  arr_delay
# 0     517.0        2.0     830.0       11.0
# 1     533.0        4.0     850.0       20.0
# 2     542.0        2.0     923.0       33.0
# 3     544.0       -1.0    1004.0      -18.0
# 4     554.0       -6.0     812.0      -25.0

# %% [markdown]
# ## Sort columns

# %% [markdown]
# 6. Sort flights to find the most delayed flights by arrival time. Hint: End your code with head(1) to only print that row.

# %%
# Solution
arr_delay_sort = df.sort_values(['arr_delay'], ascending=False)
arr_delay_sort.head(1)
# Out:
#       Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 7072        7073  2013      1    9     641.0             900     1301.0
#
#       arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 7072    1242.0            1530     1272.0      HA      51  N384HA    JFK  HNL
#
#       air_time  distance  hour  minute            time_hour
# 7072     640.0      4983     9       0  2013-01-09 09:00:00

# %% [markdown]
# 7. Find the top 5 flights that left earliest relative to their scheduled departure. Only show the tail number, date and number of minutes early they departed at.

# %%
# Solution
dep_delay_sort = df.sort_values(['dep_delay'])
dep_delay_sort[['tailnum','year','month','day','dep_delay']].reset_index(drop=True).head(5)
# Out:
#   tailnum  year  month  day  dep_delay
# 0  N592JB  2013     12    7      -43.0
# 1  N612DL  2013      2    3      -33.0
# 2  N825AS  2013     11   10      -32.0
# 3  N934DL  2013      1   11      -30.0
# 4  N208FR  2013      1   29      -27.0

# %%
#8. How could you sort all missing values to the start?

# %%
# Solution
# En la pregunta 2, sé qué columnas tienen nulos, por lo que:
df_sort_nan = df.sort_values(by=['dep_time', 'dep_delay', 'arr_time', 'arr_delay', 'tailnum', 'air_time'], na_position='first')
df_sort_nan.head()
# Out:
#       Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 1782        1783  2013      1    2       NaN            1545        NaN
# 1784        1785  2013      1    2       NaN            1601        NaN
# 2697        2698  2013      1    3       NaN             857        NaN
# 2698        2699  2013      1    3       NaN             645        NaN
# 3608        3609  2013      1    4       NaN             845        NaN
#
#       arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin dest  \
# 1782       NaN            1910        NaN      AA     133     NaN    JFK  LAX
# 1784       NaN            1735        NaN      UA     623     NaN    EWR  ORD
# 2697       NaN            1209        NaN      UA     714     NaN    EWR  MIA
# 2698       NaN             952        NaN      UA     719     NaN    EWR  DFW
# 3608       NaN            1015        NaN      9E    3405     NaN    JFK  DCA
#
#       air_time  distance  hour  minute            time_hour
# ...

# %% [markdown]
# ## Add new variables

# %% [markdown]
# 9. Currently `dep_time` and `arr_time` are convenient to look at, but hard to compute with because they’re not really continuous numbers. Convert them to number of minutes since midnight in new vars called `arr_time_min` and `dep_time_min`

# %%
# Solution
df['dep_time_min'] = (df['dep_time'] // 100) * 60 + (df['dep_time'] % 100)
df['arr_time_min'] = (df['arr_time'] // 100) * 60 + (df['arr_time'] % 100)

#lo visualizamos:

df.head()
# Out:
#    Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0           1  2013      1    1     517.0             515        2.0
# 1           2  2013      1    1     533.0             529        4.0
# 2           3  2013      1    1     542.0             540        2.0
# 3           4  2013      1    1     544.0             545       -1.0
# 4           5  2013      1    1     554.0             600       -6.0
#
#    arr_time  sched_arr_time  arr_delay  ... tailnum  origin dest air_time  \
# 0     830.0             819       11.0  ...  N14228     EWR  IAH    227.0
# 1     850.0             830       20.0  ...  N24211     LGA  IAH    227.0
# 2     923.0             850       33.0  ...  N619AA     JFK  MIA    160.0
# 3    1004.0            1022      -18.0  ...  N804JB     JFK  BQN    183.0
# 4     812.0             837      -25.0  ...  N668DN     LGA  ATL    116.0
#
#   distance  hour  minute            time_hour  dep_time_min arr_time_min
# ...

# %% [markdown]
# 10. Make a plot to compare `air_time` with `arr_time_min` - `dep_time_min`

# %%
# Solution
import matplotlib.pyplot as plt
df['flight_duration'] = df['arr_time_min'] - df['dep_time_min']
plt.figure(figsize=(8, 6))
plt.scatter(df['flight_duration'], df['air_time'], color='blue', alpha=0.5)
plt.title('Comparación entre Duración de Vuelo en minutos y Air Time')
plt.xlabel('Duración de Vuelo en minutos')
plt.ylabel('Air Time')
plt.grid(True)
plt.show()

# %% [markdown]
# 11. We expect `air_time` and `arr_time_min` - `dep_time_min` to be the same, but they’re not. Why not?
# Identify a major data issue and subtle one.

# %%
# Solution: En realidad se puede deber a diversas razones. Primero, se puede deber a problemas de datos mayor, es decir, la data se puede encontrar inconsistente por missing values.
#Además, puede haber problema de datos sutil, como por ejemplo en la diferencia horaria, ya que, así no parezca relevante, esos pequeños errores pueden resultar en diferencias significativas en los valores calculados.
#Sin embargo, creo que uno de los mayores problemas consiste en que algunos valores de arr_time_min son menores que los de dep_time_min que les corresponde.
#Lo mencionado arriba es un error porque arr_time_min siempre debe ser mayor al ser la hora de llegada transformada en minutos, por lo que la hora de salida debe ser menor al de llegada.
#De esta manera, debe de ignorarse los valores negativos de flight_duration.

# %% [markdown]
# 12. Implement your fix to the major probelm. Remake the plot from the previous question.

# %%
# Solution
# Crear nuevas columnas eliminando los valores nulos de 'air_time' y 'duracion_de_vuelo_min'
df['new_air_time'] = df['air_time'].dropna()
df['new_duracion_de_vuelo_min'] = df['flight_duration'].dropna()

# Crear un gráfico de dispersión para comparar 'duracion_de_vuelo_min' con 'air_time'
plt.figure(figsize=(8, 6))
plt.scatter(df['new_duracion_de_vuelo_min'], df['new_air_time'], color='blue', alpha=0.5)
plt.xlim(0, None)
plt.plot([0, 700], [0, 700], color='red', label='Recta diagonal')
plt.title('Comparación entre Duración de Vuelo y Tiempo en el Aire')
plt.xlabel('Duración de vuelo en minutos')
plt.ylabel('Tiempo en el aire')
plt.grid(True)
plt.show()

print('Puede observarse que mis valores reflejan cierta tendencia hacia la diagonal, que reflejaría aquellos valores iguales para las dos variables, por lo que falta aún detectar los otros errores.')
# Out:
# Puede observarse que mis valores reflejan cierta tendencia hacia la diagonal, que reflejaría aquellos valores iguales para las dos variables, por lo que falta aún detectar los otros errores.

# %%
# Grading: -1
# Major issue: overnight flights

# %% [markdown]
# 13. Find the 10 most delayed flights

# %%
# Solution
# Ordenar el DataFrame por la columna 'dep_delay' de forma descendente para obtener los vuelos más tempranos en términos de retraso en la salida
vuelos_mas_tempranos = df.sort_values(by="dep_delay", ascending=False)

# Mostrar las primeras 10 filas del DataFrame ordenado
vuelos_mas_tempranos.head(10)
# Out:
#         Unnamed: 0  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 7072          7073  2013      1    9     641.0             900     1301.0
# 235778      235779  2013      6   15    1432.0            1935     1137.0
# 8239          8240  2013      1   10    1121.0            1635     1126.0
# 327043      327044  2013      9   20    1139.0            1845     1014.0
# 270376      270377  2013      7   22     845.0            1600     1005.0
# 173992      173993  2013      4   10    1100.0            1900      960.0
# 151974      151975  2013      3   17    2321.0             810      911.0
# 247040      247041  2013      6   27     959.0            1900      899.0
# 270987      270988  2013      7   22    2257.0             759      898.0
# 87238        87239  2013     12    5     756.0            1700      896.0
#
#         arr_time  sched_arr_time  arr_delay carrier  flight tailnum origin  \
# 7072      1242.0            1530     1272.0      HA      51  N384HA    JFK
# ...

# %% [markdown]
# ## Summarizing grouped data

# %% [markdown]
# 14. Calculate average delays by destination for flights originating in NYC. Create a variable which ranks destinations from worst to best, where 1 is the worst rank.

# %%
# Solution
#Veamos los vuelos que parten de los aeropuertos JFK, EWR y LGA.
datos_nyc = df[df['origin'].isin(['JFK', 'EWR', 'LGA'])]
datos_nyc

#Retrasos promedio:
retrasos_promedio = (datos_nyc.groupby('dest')['dep_delay'].mean() + datos_nyc.groupby('dest')['arr_delay'].mean()) / 2

#Aqui vemos la rpta: Se creo una variable que ordena los destinos de peor a mejor segun su retraso promedio
retrasos_promedio_ordenados = retrasos_promedio.sort_values(ascending=False)
top_10_retrasos = retrasos_promedio_ordenados.nlargest(10)
ranking = top_10_retrasos.rank(method='max', ascending=False)
datos_rankeados = pd.DataFrame({'Retraso Promedio': top_10_retrasos, 'Ranking': ranking})
datos_rankeados
# Out:
#       Retraso Promedio  Ranking
# dest
# CAE          38.667122      1.0
# TUL          34.283109      2.0
# OKC          30.593927      3.0
# JAC          27.320346      4.0
# TYS          26.281580      5.0
# BHM          23.286088      6.0
# DSM          22.619345      7.0
# MSN          21.888057      8.0
# RIC          21.875550      9.0
# CAK          20.259608     10.0

# %% [markdown]
# 15. Which plane (`tailnum`) has the most minutes of delays total?

# %%
# Solution
# Calculamos el promedio de minutos de retraso tanto en la salida como en la llegada para cada avión
promedio_retraso_aviones = (datos_nyc.groupby('tailnum')['dep_delay'].mean() + datos_nyc.groupby('tailnum')['arr_delay'].mean()) / 2

# Ordenamos los resultados de manera descendente para identificar el avión con el mayor promedio de retraso
promedio_retraso_aviones = promedio_retraso_aviones.sort_values(ascending=False)

# Mostramos el avión con el mayor promedio de minutos de retraso
promedio_retraso_aviones.head(1)
# Out:
# tailnum
# N844MH    308.5
# dtype: float64

# %% [markdown]
# 16. Which airlines only offer flights from New York to one other airport?

# %%
# Solution

# Recogemos la base de datos de los vuelos que se originan en NYC (JFK, EWR, LGA)
df_nyc = df[df['origin'].isin(['JFK', 'EWR', 'LGA'])]

# Eliminamos duplicados basados en la columna 'carrier'
df_nyc_unique_carriers = df_nyc[['carrier']].drop_duplicates()

# Obtenemos la lista de aerolíneas sin duplicados
carrier_list = df_nyc_unique_carriers['carrier'].tolist()

# Mostramos la lista de aerolíneas
print("Lista de aerolíneas sin duplicados:")
print(carrier_list)
# Out:
# Lista de aerolíneas sin duplicados:
# ['UA', 'AA', 'B6', 'DL', 'EV', 'MQ', 'US', 'WN', 'VX', 'FL', 'AS', '9E', 'F9', 'HA', 'YV', 'OO']

# %% [markdown]
# 17. Calculate the median arrival delay by airline.

# %%
# Solution
# Calculamos la mediana de retraso de llegada para cada aerolínea
mediana_retraso_por_aerolinea = df.groupby('carrier')['arr_delay'].median()

# Mostramos la mediana de retraso por aerolínea
print(mediana_retraso_por_aerolinea)
# Out:
# carrier
# 9E    -7.0
# AA    -9.0
# AS   -17.0
# B6    -3.0
# DL    -8.0
# EV    -1.0
# F9     6.0
# FL     5.0
# HA   -13.0
# MQ    -1.0
# OO    -7.0
# UA    -6.0
# US    -6.0
# VX    -9.0
# WN    -3.0
# YV    -2.0
# Name: arr_delay, dtype: float64

# %% [markdown]
# 18. ExpressJet has a median arrival delay of -1 minutes while US Airways has a median arrival delay of -6 minutes. Does this tell you that US Airways is a more reliable airline? Why or why not?

# %%
# Solution
#En realidad, la mediana del retraso de llegada por sí sola no proporciona suficiente información para concluir si una aerolínea es más confiable que otra. 
# La mediana indica el valor central de un conjunto de datos ordenados, y en este caso, una mediana negativa sugiere que, en general, los vuelos de ambas aerolíneas tienden a llegar antes de la hora programada.
#Sin embargo, la confiabilidad de una aerolínea no se limita solo al retraso de llegada. Por eso, se pueden usar otras métricas más especializadas.
#Pero, como respuesta, podemos decir que, meramente en terminos de retraso de llegada, US airways tiende a ser más confiable que Express Jet.

# %% [markdown]
# 19. Median arrival delay may not be the best metric for our needs. Brainstorm at least 4 additional ways to assess the typical delay characteristics of a group of flights.

# %%
# Solution
#Existen diversas formas de evaluar las características de retraso en un grupo de vuelos, más allá de la mediana del retraso de llegada. 
#La media aritmética ofrece una medida promedio sensible a los valores extremos, la desviación estándar proporciona información sobre la variabilidad de los retrasos, y la proporción de vuelos puntuales directamente indica la puntualidad de la aerolínea. 
#Además, el análisis de tendencias temporales, como patrones en diferentes días o horas, puede ofrecer una comprensión más profunda de los momentos específicos en los que la puntualidad podría ser más desafiante. 
#Así, el conjunto de estas métricas proporciona una visión más completa de las características de los retrasos y facilita una evaluación más robusta del rendimiento de la aerolínea.

# %% [markdown]
# 20. Write a code which calculates your delay measures separately by airline. Do particular airlines perform poorly on multiple metrics?

# %%
# Solution
#Calculamos las medidas de retraso individualmente para cada aerolínea
promedio_retraso_salida = df.groupby('carrier')['dep_delay'].mean()
promedio_retraso_llegada = df.groupby('carrier')['arr_delay'].mean()
variacion_retraso_salida = df.groupby('carrier')['dep_delay'].std()
variacion_retraso_llegada = df.groupby('carrier')['arr_delay'].std()
percentil25_retraso_salida = df.groupby('carrier')['dep_delay'].quantile(0.25)
percentil25_retraso_llegada = df.groupby('carrier')['arr_delay'].quantile(0.25)
percentil75_retraso_salida = df.groupby('carrier')['dep_delay'].quantile(0.75)
percentil75_retraso_llegada = df.groupby('carrier')['arr_delay'].quantile(0.75)

# Construir un DataFrame con los resultados
df_medidas_retraso = pd.DataFrame({
    'Aerolínea': promedio_retraso_salida.index,
    'Promedio Retraso en Salida': promedio_retraso_salida.values,
    'Promedio Retraso en Llegada': promedio_retraso_llegada.values,
    'Variación Retraso en Salida': variacion_retraso_salida.values,
    'Variación Retraso en Llegada': variacion_retraso_llegada.values,
    'Percentil 25 Retraso en Salida': percentil25_retraso_salida.values,
    'Percentil 25 Retraso en Llegada': percentil25_retraso_llegada.values,
    'Percentil 75 Retraso en Salida': percentil75_retraso_salida.values,
    'Percentil 75 Retraso en Llegada': percentil75_retraso_llegada.values
})

df_medidas_retraso = df_medidas_retraso.sort_values(by=['Promedio Retraso en Salida', 'Promedio Retraso en Llegada'], ascending=False)

# Imprimir el resultado para análisis
df_medidas_retraso.head()
# Out:
#    Aerolínea  Promedio Retraso en Salida  Promedio Retraso en Llegada  \
# 6         F9                   20.215543                    21.920705
# 5         EV                   19.955390                    15.796431
# 15        YV                   18.996330                    15.556985
# 7         FL                   18.726075                    20.115906
# 14        WN                   17.711744                     9.649120
#
#     Variación Retraso en Salida  Variación Retraso en Llegada  \
# 6                     58.362648                     61.645997
# 5                     46.552354                     49.861469
# 15                    49.172266                     52.922234
# 7                     52.661600                     54.087671
# 14                    43.344355                     46.877702
#
#     Percentil 25 Retraso en Salida  Percentil 25 Retraso en Llegada  \
# 6                             -4.0                             -9.0
# ...

# %%
print('Podemos ver que la aerolínea F9 es la peor según la mediana y media.')
print('Sin embargo, se debe destacar los valores de los percentiles, los cuales refleja que este valor promedio resulta en un outlier en el caso de la salida, por lo que no es confiable este resultado.')
print('Por ello, es importante analizar estas métricas, conociendo que la media es afectada por los outliers y no la mediana.')
print('Asimismo, la desviación estándar nos logrará medir que tan variables son estos resultados.')
# Out:
# Podemos ver que la aerolínea F9 es la peor según la mediana y media.
# Sin embargo, se debe destacar los valores de los percentiles, los cuales refleja que este valor promedio resulta en un outlier en el caso de la salida, por lo que no es confiable este resultado.
# Por ello, es importante analizar estas métricas, conociendo que la media es afectada por los outliers y no la mediana.
# Asimismo, la desviación estándar nos logrará medir que tan variables son estos resultados.
